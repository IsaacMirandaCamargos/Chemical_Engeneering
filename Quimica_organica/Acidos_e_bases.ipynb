# %% [markdown]
# <h1 align="center"> Quimica organica 1: ácidos e bases<h1>

# %% [markdown]
# ![image.png](attachment:cbb2d669-d325-416e-8159-f170f2302fc8.png)

# %% [markdown]
# <h1> # Ácido e base de Bronsted-lowry

# %% [markdown]
# Os **ácidos e bases** de bronsted-lowry consistem nas seguintes definições:
#
# - **Ácido**: O ácido de bronsted-lowry consiste em uma substância que pode doar prótons.
#
# - **Base**: A base de bronsted-lowry consiste em uma subtância que pode receber prótons.
#
# Ademais, temos os conceitos de **ácidos e base conjugada** como sendo a parcela restante dos ácidos e bases:
#
# ![image.png](attachment:08b96ead-b075-4e55-b324-53676aa46d5f.png)

# %% [markdown]
# <h1> # Ácido e base de Lewis

# %% [markdown]
# Os **ácidos e bases** de Lewis consistem nas seguintes definições:
#
# - **Ácido**: Os ácidos de Lewis são receptores de pares de eletrons.
#
# - **Base**: As bases de Lewis são doadoras de pares de eletrons.
#
# Também temos os conceitos de **ácidos e base conjugada** como sendo a parcela restante dos ácidos e bases:
#
# ![image.png](attachment:2f022ac9-180d-490c-8b5d-d5aa557eecc2.png)

# %% [markdown]
# <h1> # Força dos ácidos

# %% [markdown]
# O **coeficiente de dissociação ácida** consiste em uma constante expressa pela expressão genérica abaixo:
#
# ![image.png](attachment:6453774a-1e6c-4cbf-bc4f-32a026357f64.png)
#
# Quanto maior o **Ka** maior a dissociação do ácido e maior sua força. Além disso, utiliza os valores de **pKa** tabelados para comparar a força de ácidos.

# %% [markdown]
# <h1> # Força das bases

# %% [markdown]
# O **coeficiente de dissociação base** consiste em uma constante expressa pela expressão genérica abaixo:
#
# ![image.png](attachment:f23ac754-3140-45ed-8430-14af7b596d15.png)
#
# Quanto maior o **Kb** maior a dissociação da base e maior sua força. Além disso, utiliza os valores de **pKb** tabelados para comparar a força das bases.

# %% [markdown]
# <h1> # Eletronegatividade e acidez

# %% [markdown]
# A eletronegatividade dos elementos está diretamente ligada a acidez dos mesmos, desse modo quanto mais eletronegativo mais acido será o elemento.
#
# Abaixo temos a tabela periódica e a correspondente eletronegatividade de elementos comuns:
#
# ![image.png](attachment:ef87a624-7ad1-4ec5-8d83-aad7d683ba63.png)
#
# Abaixo temos alguns ácidos e seus respectivos pKa para reforçar o efeito da eletronegatividade:
#
# ![image.png](attachment:30663d74-ee4e-438f-b747-a28052f5d8ec.png)

# %% [markdown]
# <h1> # Tamanho dos átomos e acidez

# %% [markdown]
# Com relação ao tamanho dos átomos ligantes, quanto maior a diferença entre o **H** e o **átomo ligante** mais fácil será o hidrogênio abandonar a ligação.
#
# Desse modo, quanto maior a diferença de tamanho dos átomos em uma ligação, maior a acidez de uma ácido:
#
# ![image.png](attachment:74622cd2-1a15-4f91-a60c-b6cca24ec1b7.png)

# %% [markdown]
# <h1> # Efeito indutivo

# %% [markdown]
# O efeito indutivo consiste na existência de átomos muito eletronegativos que puxam a densidade eletronica da molécula e **estabilizam a base conjugada**.
#
# Abaixo temos 1 exemplo de um efeito indutivo ocorrendo, ele estabiliza a base conjugada, desestabilizando o ácido, tornando o ácido mais forte:
#
# ![image.png](attachment:e38fd33b-1d3f-4e8a-93a2-91a7d8106c74.png)
#
# Abaixo temos 1 exemplo de dois elementos realizando o efeito indutivo, sendo F mais eletronegativo que o Cl:
#
# ![image.png](attachment:da2bbce8-c9ef-42f0-a217-06f734285e8e.png)
#
# Abaixo temos a relação entre a distância do elemento eletronegativo e o efeito indutivo:
#
# ![image.png](attachment:cb444577-1df7-45a6-8ae9-6777aeb75c13.png)
#
# Além disso, existe os casos que elementos eletropositivos empurram a densidade eletronica e **estabilizam a base conjugada**. Um caso disso está abaixo:
#
# ![image.png](attachment:45329225-3ba8-4671-a5e3-80f7da4f27b8.png)

# %% [markdown]
# <h1> # Hibridização e acidez

# %% [markdown]
# Com relação a hibridização, quanto maior o carater **s** do elemento hibridizado, maior a eletronegatividade dele.
#
# Desse modo, temos que **maior carater s maior será a acidez**:
#
# ![image.png](attachment:03e7e1ea-7c34-4a6d-b759-071a30eb8edf.png)

# %% [markdown]
# <h1> # Deslocalização e ressonância

# %% [markdown]
# Quando ocorre a existência de uma ligação dupla adjacente a um hidrogênio a ser desprotenado de um ácido, temos que sua base conjugada será mais estavel e, consequentemente, seu ácido será mais forte.
#
# Em resumo, a ligação dupla ocasionara o efeito de ressonância estabilizando a base conjugada:
#
# ![image.png](attachment:ec7a1493-f4fa-4dc3-9d39-e61d2d07fa17.png)
#
# Abaixo temos a representação da ressonância:
#
# ![image.png](attachment:07969dc3-dd75-4f4e-bbea-02ccd436dfba.png)
