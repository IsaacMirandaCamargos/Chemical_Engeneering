# %% [markdown]
# <h1 align="center"> Quimica organica 1: Orbitais e ligações <h1>

# %% [markdown]
# ![image.png](attachment:0f97534c-f5b5-4556-8c50-252e9b0a0620.png)

# %% [markdown]
# <h1> # Orbitais eletronicos

# %% [markdown]
# Os eletrons em um atomo são organizados em camadas/orbitais, de modo que as camadas são definidas de acordo com o nível de energia que elas possuem.
#
# Desse modo, temos as seguintes orbitais e eletrons por orbital:
#
# ![image.png](attachment:d10e6843-79b4-43ef-b34a-f9f77c39c00b.png)

# %% [markdown]
# <h1> # Sub-orbitais eletronicos

# %% [markdown]
# Ademais, os orbitais eletronicos são divididos em sub-orbitais de modo que possam se alocar os eletrons dentro dele.
#
# Os sub-orbitais são nomeados de **s, p, d, f** e comportam diferentes quantidades de eletrons:
#
# ![image.png](attachment:da91b5ba-d174-4d38-ae28-f1263cef4c5c.png)
#
# Dentro dos sub-orbitais, os eletrons fica agrupados em pares de modo que permitem ou impedem novas ligações:
#
# ![image.png](attachment:65c3fa82-f48f-4a85-b0c0-898bcd29d3e9.png)

# %% [markdown]
# <h1> # Hibridização: Carbono

# %% [markdown]
# A hibridização consiste na separação de um par de eletron de modo que os orbitais se aproximem e pemitam mais ligações.
#
# Abaixo temos a **hibridização sp3 do carbono**: (25% carater **s**)
#
# ![image.png](attachment:869ee901-b57e-404a-b2f9-99b4b58fdfee.png)
#
# Abaixo temos a **hibridização sp2 do carbono**: (33% carater **s**)
#
# ![image.png](attachment:381d85e1-ea1f-4a5f-bdaa-50b125cdffb6.png)
#
# Por fim, temos a **hibridização sp do carbono**: (50% carater **s**)
#
# ![image.png](attachment:9d12feb2-d08c-4ab3-b35a-fac5e0bf172d.png)

# %% [markdown]
# <h1> # Tipos de ligações

# %% [markdown]
# Cada tipo de orbital pode realizar 1 tipo de ligação, podendo elas serem **sigma** ou **pi**.
#
# Desse modo, abaixo temos o tipo de ligação que cada orbital pode realizar:
#
# ![image.png](attachment:cabf9192-3eaa-432f-b764-2dd2863c9cb9.png)
#
# Orbitais hibridos realizam ligação **sigma**.
