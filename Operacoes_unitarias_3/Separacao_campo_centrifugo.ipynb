# %% [markdown]
# <h1 align="center"> Operações unitárias 3

# %% [markdown]
# ![image.png](attachment:f22da81c-97bf-43a3-8c13-1ebd771bc938.png)

# %% [markdown]
# ---

# %% [markdown]
# <h1 align="center"> Centrifugas separação solido-liquido

# %% [markdown]
# <h1> # Balanço de forças na particula:

# %% [markdown]
# Considere uma particula inserida no seguinte esquema, sob ação da força centrifuga:
#
# ![image.png](attachment:466418b2-e45a-4e9b-b39f-bbaf4f0cfaad.png)
#
# Realizando os balanços de forças para está particula, temos:
#
# ![image.png](attachment:e187b8c8-ed88-45b3-859b-11cc1a7cecf7.png)
#
#
# Onde:
#
# - **Ω**: Velocidade angular [rad/t]

# %% [markdown]
# <h1> # Efeito Centrifugo:

# %% [markdown]
# Diversas vezes queremos saber quantas vezes a **força centrifuga** é maior que a **força gravitacional**, para tal foi definida a grandeza **Efeito centrifugo (K)**:
#
# ![image.png](attachment:968de5bc-f6f3-4429-b048-21761867fcd5.png)
#
# - Onde:
#
# - **N**: Número de rotações [rps]
# - **Dc**: Diâmetro da rotação [m]

# %% [markdown]
# <h1> # Tipos de centrífugas:

# %% [markdown]
# A diversos tipos de centrifugas utilizadas para separação de solidos ou liquidos em uma mistura:
#
# ![image.png](attachment:0ace21db-137c-4d4c-be3f-8e8fe7d44903.png)
#
# Ademais, iremos focar nas **centrifugas decantadoras** (tubular, multicâmera, de cesto, de disco) pois estas centrifugas utilizam apenas das forças gravitacionais e centrifugas para separar as substancias.
#
# Ademais, temos que elas operam nos respectivos regimes:
#
# - **Batelada**: Centrifuga tubular e multicâmera.
# - **Semi-Continua**: Centrifuga de cesto.
# - **Continua**: Centrifuga de disco e helicoidal(a de disco pode operar em todos regimes)

# %% [markdown]
# <h1> # Vantagens e desvantagens centrífugas decantadoras:

# %% [markdown]
# ![image.png](attachment:6236f0f3-bfe1-42f3-836c-534c9c23d76e.png)

# %% [markdown]
# <h1> # [ 1 ] Dimensionamento: Centrifuga Tubular

# %% [markdown]
# Considere a figura abaixo:
#
# ![image.png](attachment:e0d34143-4069-4f51-82ad-50627ea29443.png)
#
# Onde:
#
# - **Ro**: Raio do tubo de alimentação.
# - **R1**: Raio da centrifuga que devide a área da coroa em 2 áreas iguais.
# - **R**: Raio da centrifuga.
# - **π.(R²-Ro²)**: Área da coroa da centrifuga.
# - <b>d*</b>: Diâmero de corte ( diâmetro que as particulas são coletadas com 50% de eficiência.
#
# Além disso, para dimensionar a centrigua tubular, considere as seguintes hipoteses:
#
# - Movimentação das particulas no **Regime de Stokes**.
# - Particulas igualmente espalhadas em (z=0) na **área da coroa**.

# %% [markdown]
# <h1> # [ 2 ] Dimensionamento: Centrifuga Tubular

# %% [markdown]
# O raio **R1** será definido por:
#
# ![image.png](attachment:57c6c9be-7716-4dd7-ac4e-ffa938884d4c.png)
#
# Dito isso, sabe-se que a particula saindo de **Zo** e subindo até a altura **L** se deslocará na direção axial **y** e na direção radial **r**.
#
# Desse modo, para a particula de diâmetro <b>d*</b> seja coletada temos que o tempo necessário para ambos deslocamento sejam iguais:
#
# ![image.png](attachment:cc937d52-a4ec-40ea-83a7-c20a9d6a0341.png)
#
# - Observação: Para outras centrifugas utiliza-se a seguinte expressão para o calculo de **∑**:
#
# ![image.png](attachment:85e87c74-5e6a-4729-8245-3350361d0224.png)

# %% [markdown]
# <h1> # [ 3 ] Dimensionamento: Resumo

# %% [markdown]
# Visto as deduções dase equações, iremos resumi-las em sequência:
#
# ![image.png](attachment:ef236be1-790a-4b85-a4c8-63d493e0cd06.png)

# %% [markdown]
# <h1> # Eficiência de coleta:

# %% [markdown]
# Tratando da separação solido-liquido, podemos determinar a **eficiência individual de coleta** e a **eficiência global de coleta**.
#
# Para tal, sabe-se que a **eficiência individual de coleta** consiste na **%** de particulas de diâmetro **D** que foram coletadas:
#
# ![image.png](attachment:5a5b20eb-5ac0-4076-a8af-0283cdb7218f.png)
#
# Já a **eficiência global de coleta** consiste na **massa coletada / massa alimentada** de particulas, também expressa por:
#
# ![image.png](attachment:342a8b10-722c-4cb1-927e-7140735af2ab.png)
