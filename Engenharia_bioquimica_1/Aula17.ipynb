# %% [markdown]
# <h1 align="center" style="color:gray">Reator Enzimático</h1>

# %% [markdown]
# ---

# %% [markdown]
# O reator enzimático é um recipiente onde se procede uma reação catalisada por uma enzima. Nestes reatores é necessária:
#
# - Uniformidade na distribuição de nutrientes
# - Aeração
# - Condições adequadas de pH e temperatura
# - Design adequado.
#
# Os reatores enzimáticos podem ser em **batelada** ou **continuo**, além disso podem ter **enzimas livres** ou **enzimas imobilizadas**.

# %% [markdown]
# ---

# %% [markdown]
# <h2> # Reatores enzimáticos: Enzimas livres

# %% [markdown]
# Os reatores enzimáticos com enzimas livres consistem em:
#
# - **Reator tipo tanque agitado (STR)**: Tanques cilíndricos aerados e agitados com agitação mecânica interna e entrada de ar na parte inferior.
#
# ![image.png](attachment:6ee07553-c071-4795-b5b1-5d21081c6455.png)
#
# - **Reatores pneumáticos**: Neste reator, o ar é injeado e disperso sem agitação mecânica e as bolhas são responsáveis pela agitação e aeração do sistema.
#
# ![image.png](attachment:a560fe2d-b4ba-42ed-8358-54165f117b0d.png)

# %% [markdown]
# <h2> # Reatores enzimáticos: Enzimas imobilizadas

# %% [markdown]
# Os reatores enzimáticos com enzimas imobilizadas consistem em:
#
# - **Reatores para enzimas imobilizadas em leito fixo**: Nestes reatores, as células ou enzimas são imobilizadas em partículas sólidas inertes (vidro, plástico, fibra vidro, argilas porosas, madeira) ou partículas de gel.
#
# ![image.png](attachment:e8f555ef-b6c8-413a-914e-29c4ae760ded.png)
#
# - **Reatores para enzimas imobilizadas em leito fixo**: Nestes reatores, as células são imobilizadas em pequenas partículas que ficam em suspensão e se movem com o líquido.
#
# ![image.png](attachment:5dd3005f-d25c-46ad-85a2-bb70c151aea7.png)

# %% [markdown]
# <h1> # Reator enzimático: Operação batelada

# %% [markdown]
# No reator batelada, ele é carregado com meio de cultura, inoculado com o microrganismo, e o processo segue até o esgotamento de nutrientes e/ou acúmulo do produto de interesse.
#
# Ademais, o sistema é fechado, ou seja não ocorre adição de nutrientes (apenas ar, ácido e base) durante o
# cultivo.
#
# Desse modo, considere o volume de controle abaixo:
#
# ![image.png](attachment:d5e577fb-e494-43ef-b9ee-bb6e469d7dda.png)
#
# Realizando o **balanço de massa do substrato** temos:
#
# ![image.png](attachment:7ac2461f-eec0-49df-8730-2fa222828296.png)
# - **Exemplo**:
#
# ![image.png](attachment:a17c009d-2062-42bb-8976-bbedfb902ea1.png)
#
# - **Resposta**:
# ![image.png](attachment:fe01b614-d5d5-49a4-addf-76286bb760d9.png)

# %% [markdown]
# <h1> # Reator enzimático: Operação batelada (Com desativação)

# %% [markdown]
# Considerando a desativação de enzimas:
#
# ![image.png](attachment:754e4104-f175-4821-99bb-dbbca4393588.png)
#
# O balanço de massa de substrato para o reator batelada fica da forma:
#
# ![image.png](attachment:37e8b8eb-a762-4314-b656-8dc2f9d4b209.png)
#
# Integrando a expressão chegamos em:
#
# ![image.png](attachment:d56e55bb-6994-45e8-8ffc-ffa08a74b9dc.png)
#
# - **Exemplo**:
#
# ![image.png](attachment:f4363987-55b9-4a5d-99a2-639d45d8a230.png)
#
# - **Resposta**:
# ![image.png](attachment:f14e2f7d-62f1-4d0a-8c03-b2a0358862ec.png)

# %% [markdown]
# <h1> # Reator enzimático: Operação continua (CSTR)

# %% [markdown]
# No reator enzimático continuo de mistura (CSTR) temos que o meio é adicionado de forma contínua e os produtos da fermentação também são continuamente removidos.
#
# Desse modo, considere o volume de controle abaixo:
#
# ![image.png](attachment:800baa99-2325-4ccd-aff6-251289783a87.png)

# %% [markdown]
# ![image.png](attachment:68825f17-50c3-4ba3-9bae-caacc9634b49.png)

# %% [markdown]
# ![image.png](attachment:328d62b5-3250-46d4-a826-c834bb08faee.png)

# %% [markdown]
# ![image.png](attachment:b7889e68-46ac-48f8-bc53-b9357d92096e.png)

# %% [markdown]
# ---

# %% [markdown]
# <h1> # Reator enzimático: Operação continua (PFR)

# %% [markdown]
# No reator enzimático continuo tubular (PFR) temos que o meio é adicionado de forma contínua e os produtos da fermentação também são continuamente removidos.

# %% [markdown]
# ![image.png](attachment:c6986e6a-10ff-40ee-a597-18632b0abe7a.png)
