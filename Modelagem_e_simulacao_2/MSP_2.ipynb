# %% [markdown]
# <h1 align="center"> Modelagem e simulação 2

# %% [markdown]
# <center><img src="https://i.pinimg.com/564x/5c/be/95/5cbe959a1fbf83c066d4fb57e454024e.jpg" width="500px" ></center>

# %% [markdown]
# ---

# %% [markdown]
# <h1 align="center"> Sumário

# %% [markdown]
# <h1> # Sumário

# %% [markdown]
# A seguir temos o sumário dos conteúdos abordados na diciplina:
#
# - Análise de processos químicos no estado estacionário
# - Linearização
# - Análise do plano de fases
# - Bifurcação de sistemas dinâmicos
# - Introdução à identificação de sistemas
#
# Avaliações e notas:
#
# - AV1 - 40%  [02/02/2023]
# - AV2 - 40%  [30/03/2023]
# - Exercicios em sala - 10%
# - Atividades práticas - 10%
#
# Contato:
#
# - nadiagsousa@gmail.com
# - atendimento - Terça-feira 10-12h - Bloco N, sala N102 B
#
# Bibliografia:
#
# - BEQUETTE, B.W. Process Dynamics - Modeling, Analysis and Simulation. Prentice Hall, Upper. Saddle River. 2003;
# - BARROSO L.C. et al. Cálculo Numérico: com Aplicações, 2a. ed., São Paulo: Harbra, 1987;
# - RUGGIERO, MÁRCIA A. GOMES; LOPES, VERA LÚCIA DA ROCHA.

# %% [markdown]
# ---

# %% [markdown]
# <h1 align="center"> Linearização de modelos não lineares

# %% [markdown]
# <h1> # Representação de modelos

# %% [markdown]
# Considere o modelo dinâmico onde:
#
# - x: Variaveis de estado do modelo.
# - u: Variaveis de entrada. (São variáveis dependentes)
# - Ẋ: Variação das variaveis de estado.
#
# Podemos representa-lo por:
#
# ![image.png](attachment:fe702f08-496c-4f86-bb14-d94be9cf891b.png)
#
# - f(x,u): Vetor de funções lineares.

# %% [markdown]
# <h1> # Representação por Espaço de estados

# %% [markdown]
# Considerando a representação anterior, é possivel representar o mesmo modelo pela utilização da **representação por espaço de estados** o qual possui a forma geral:
#
# ![image.png](attachment:c5c3e636-e920-4377-a505-65a677d7dc7c.png)
#
# - A: Matriz de estados. (coeficiêntes)
# - B: Matriz de entradas do modelo. (coeficiêntes)

# %% [markdown]
# <h1> # Linearização de modelos não lineares

# %% [markdown]
# A linearização de modelos não lineareas consiste em:
#
# - Encontrar a aproximação linear de uma função em dado ponto **(hiperplano tangente)**.
# - No estudo de sistemas dinâmicos a linearização é um método para **avaliar a estabilidade local** de um ponto de equilíbrio de um sistema de equações diferenciais não lineares ou sistemas dinãmicos discretos.
# - A aproximação de modelos dinâmicos não lineares em modelos linearizados tem como objetivos fornecer **informações qualitativas** do comportamento do sistema **em torno de um ponto**.
#
# Com relação ao ponto escolhido para a linearização temos:
#
# - O ponto de linearização é o ponto com pequenas variações, ou seja, os sinais envolvidos tem que possuir pequena amplitude.
# - No maior parte dos casos utiliza-se o **ponto de quilibrio**, também conhecido como ponto de operação ou estado estacionário.

# %% [markdown]
# <h1> # Métodos de linearização: Expansão em série de Taylor

# %% [markdown]
# A série de Taylor é uma expansão ao redor de um ponto. Neste caso, escreveremos a série de Taylor da seguinte forma:
#
# ![image.png](attachment:e4bf8915-7174-4e80-b120-1c693220c26a.png)
#
# Utilizaremos o ponto do estado estacionário **(xs)** para nossas linearizações.

# %% [markdown]
# <h1> # [ 1 ] Linearização do modelo unidimensional

# %% [markdown]
# Considere o modelo não linear:
#
# ![image.png](attachment:10152904-c8f1-4f42-919b-747a67e40375.png)
#
# Expandindo a função pela série de Taylor em torno do ponto de estado estacionário **(x<sub>s</sub>)** é truncando no segundo termo:
#
# ![image.png](attachment:22b287d5-d6c6-4b9d-886c-2e45e6666ca3.png)
#
# Onde:
#
# ![image.png](attachment:2676fb96-5ad6-45ad-b97a-43b939d4ec05.png)

# %% [markdown]
# <h1> # [ 2 ] Linearização do modelo unidimensional

# %% [markdown]
# Considere o modelo não linear:
#
# ![image.png](attachment:23ca60b7-5bc5-49d8-bb87-cdd640f8482c.png)
#
# Expandindo a função pela série de Taylor em torno do ponto de estado estacionário **(x<sub>s</sub>, u<sub>s</sub>)** é truncando no segundo termo:
#
# ![image.png](attachment:48b8eaa2-54db-4049-83b4-d713ffe8d6a8.png)

# %% [markdown]
# <h1> # Exemplo: Linearização unidimensional

# %% [markdown]
# ![image.png](attachment:a81f73d9-17cc-4bfe-aeb5-36a4e3b82ed4.png)

# %% [markdown]
# <h1> # Linearização do modelo Bidimensional

# %% [markdown]
# Considere o modelo não linear:
#
# ![image.png](attachment:fa915201-8a23-4663-b1b4-b9abc263dbe9.png)
#
# Expandindo a função pela série de Taylor em torno do ponto de estado estacionário **(x<sub>1s</sub>, x<sub>2s</sub>, u<sub>s</sub>)** é truncando no segundo termo:
#
# ![image.png](attachment:c61ff47b-4ad0-4de4-8dfc-62995537473c.png)
#
# Onde:
#
# ![image.png](attachment:67d5f594-d710-4385-b127-6c7b547461f6.png)

# %% [markdown]
# <h1> # Exemplo: Linearização Bidimensional

# %% [markdown]
# - Questão:
#
# ![image.png](attachment:33bafb17-c0d3-4e8b-97a6-7945b549375b.png)
#
# - Resposta:
#
# ![image.png](attachment:86bbc232-5a33-4a40-a51d-8480567af1ae.png)

# %% [markdown]
# <h1> # Linearização do modelo Multidimensional

# %% [markdown]
# A linearização e representação em espaço de estados para modelos multidimensionais consiste em:
#
# ![image.png](attachment:f9eebde2-b8a7-415a-a50b-53076bbaf8cd.png)
