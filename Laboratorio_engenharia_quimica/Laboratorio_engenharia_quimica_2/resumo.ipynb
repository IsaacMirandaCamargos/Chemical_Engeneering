# %% [markdown]
# ---

# %% [markdown]
# <h1 align="center"> Laboratorio de Engenharia Química

# %% [markdown]
# <h1> Sumario:

# %% [markdown]
# ![image.png](attachment:a464b5c0-f899-4a74-b3fd-70bc77b09759.png)
