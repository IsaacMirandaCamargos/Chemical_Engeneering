# %% [markdown]
# ---

# %% [markdown]
# <h1 align='center'>Planejamento de produção e Controle de Qualidade</h1>

# %% [markdown]
# <h2><u>Introdução:</u></h2>

# %% [markdown]
# Neste caderno iremos ver um resumo sucinto sobre PPCQ.

# %% [markdown]
# <h2><u>Administração da produção:</u></h2>

# %% [markdown]
# - **Funções**: A seguir estão as funções gerais da administração de produção, porem haverão outras a depender da empresa e/ou serviço.
#
# ![image.png](attachment:e9a282b2-23b6-464f-b199-69602a76fc3e.png)

# %% [markdown]
# <h2><u>Processo de Transformação:</u></h2>

# %% [markdown]
# A seguir temos o modelo geral do processo de transformação:
#
# ![image.png](attachment:a50c5f73-99fc-4c33-a862-931e6c0b0e26.png)

# %% [markdown]
# <h2><u>Tipos de processos:</u></h2>

# %% [markdown]
# ![image.png](attachment:c1a0b13e-43f5-47ea-904a-44a72905518c.png)

# %% [markdown]
# <h2><u>Os 4Vs da produção:</u></h2>

# %% [markdown]
# A seguir tem-se os 4Vs da produção:
#
# ![image.png](attachment:f9695610-2ccb-467a-8c72-147c6a69f28e.png)
