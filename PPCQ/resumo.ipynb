# %% [markdown]
# ---

# %% [markdown]
# <h1 align='center'>Planejamento de produção e Controle de Qualidade</h1>

# %% [markdown]
# <h2><u>Introdução:</u></h2>

# %% [markdown]
# Neste caderno iremos ver um resumo sucinto sobre PPCQ.

# %% [markdown]
# ---

# %% [markdown]
# <h1 align='center'>Processos</h1>

# %% [markdown]
# <h2><u>Processos:</u></h2>

# %% [markdown]
# Processos, no contexto de planejamento de produção e controle de qualidade, referem-se ao conjunto de atividades sequenciais ou interdependentes que são realizadas para transformar insumos (como matérias-primas, mão de obra, informações) em produtos ou serviços finais. Esses processos são fundamentais para garantir a eficiência e a eficácia da produção, assegurando que os produtos ou serviços atendam às especificações de qualidade e às expectativas dos clientes. Eles podem variar desde procedimentos simples até fluxos de trabalho complexos e envolvem diversas etapas, como design, fabricação, inspeção e entrega.
#
# Na sequência vemos como funciona 1 processo de transformação e os tipos de processo:
#
# ![image.png](attachment:e0adbd3c-bd28-4dc5-88c1-98385a2341bf.png)

# %% [markdown]
# ---

# %% [markdown]
# <h1 align='center'>Produção</h1>

# %% [markdown]
# <h2><u>Produção:</u> Administração</h2>

# %% [markdown]
# - **Funções**: A seguir estão as funções gerais da administração de produção, porem haverão outras a depender da empresa e/ou serviço.
#
# ![image.png](attachment:6dbd9ccc-34d8-4382-8b69-84731962e1e0.png)

# %% [markdown]
# <h2><u>Produção:</u> Modelos e 4V's</h2>

# %% [markdown]
# A seguir há os modelos de produção e os 4V's da produção:
#
# ![image.png](attachment:c7176884-7ca4-41aa-8923-54f75ca9bcbb.png)

# %% [markdown]
# <h2><u>Produção:</u> Layout</h2>

# %% [markdown]
# A seguir veremos os tipos de arranjos para sistemas de produção:
#
# ![image.png](attachment:327d2eb3-e3f0-4ba8-9a4c-2c481c5033c6.png)
#
# Nesse contexto, temos as explicações de cada tipo de arranjo:
#
#
# - **Arranjo posicional**: Neste tipo de arranjo, o produto permanece fixo em uma posição devido ao seu tamanho, peso ou forma, e todos os recursos necessários para a produção, como equipamentos, mão de obra e componentes, são movidos até ele conforme necessáris.
#
# - **Arranjo funcional**: Também conhecido como layout por processo, neste arranjo, recursos similares ou que realizam funções semelhantes são agrupados juntos. Por exemplo, todas as furadeiras estarão em uma área, todas as fresadoras em outra, e assim por diates.
#
# - **Arranjo celular**: Este tipo de arranjo é um híbrido entre o arranjo funcional e o arranjo por produto. As máquinas são organizadas em "células" cada uma das quais é dedicada à produção de um tipo específico de produto ou parte, facilitando o fluxo de materiais e reduzindo o tempo de prepaerado.
#
# - **Arranjo por produto**: Também conhecido como layout em linha ou layout de produto, este tipo é usado para a produção em massa de um único produto ou produtos muito similares. As máquinas e equipamentos são dispostos em sequência, de modo que o produto se move linearmente de uma estação de trabalho para a próxima, com cada estação realizando uma etapa específica do processo de pp

# %% [markdown]
# ---

# %% [markdown]
# <h1 align='center'>Produção: Planejamento e controle</h1>

# %% [markdown]
# <h2><u>Conceitos:</u></h2>

# %% [markdown]
# A seguir veremos alguns conceitos importantes:
#
# - **Demanda Dependente:** A demanda dependente é calculada com base na necessidade de produtos finais. Comum em ambientes de produção e montagem.
# - **Demanda Independente:** Influenciada por fatores de mercado externos, como tendências e preferências do consumidor. Mais imprevisível e variável.
# - **Tempo de atravessamento (P)**: O tempo de atravessamento, também conhecido como lead time, é o período total necessário para completar um processo de produção desde o início até o fim.
# - **Tempo de demanda (D)**: Tempo total que os clientes precisam esperar entre solicitar o serviço ou produto e recebê-lo.
# - **Planejamento de Produção:** Processo de decidir sobre os métodos e a sequência de operações de manufatura, estabelecendo cronogramas e alocando recursos para a produção de bens ou serviços.
# - **Controle:** Envolve o conjunto de procedimentos implementados para realizar pequenas intervenções no plano de modo a garantir seu sucesso.

# %% [markdown]
# <h2><u>Produção:</u> Modelos e priorização</h2>

# %% [markdown]
# A seguir veremos conceitos de carregamento, priorização e planejamento:
#
# - **Modelos de planejamento**:
#     - **Para frente**: O trabalho se inicia assim que a demanda chega.
#     - **Para trás**: O trabalho se inicia no ultimo momento para que a demanda não sofra atraso.
#
# - **Modelos de Carregamento:**
#     - **Carregamento Finito:** Planejamento de produção que considera a capacidade limitada de recursos (máquinas, mão de obra, materiais) para agendar a produção.
#     - **Carregamento Infinito:** Planejamento de produção que não leva em conta as limitações de capacidade, presumindo recursos ilimitados.
#
#
# - **Regras de Priorização em Produção:**
#     - **LIFO (Last In, First Out):** O último item a entrar no processo de produção é o primeiro a ser processado.
#     - **FIFO (First In, First Out):** O primeiro item a entrar no processo de produção é o primeiro a ser processado.
#     - **LOT (Longest Operation Time):** Prioriza itens que têm o maior tempo de operação restante.
#     - **SOT (Shortest Operation Time):** Prioriza itens que têm o menor tempo de operação restante.
#     - **EED (Earliest Due Date):** Prioriza itens com a data de vencimento mais próxima.

# %% [markdown]
# <h2><u>Produção:</u> Controle</h2>

# %% [markdown]
# A seguir veremos os conceitos de MPS, MRP e ERP:
#
# - **MPS (Master Production Schedule):** O MPS é um plano detalhado que especifica quais produtos serão produzidos, em que quantidades e em que momentos.
#
# - **MRP (Material Requirements Planning):** O MRP é um sistema de planejamento e controle de inventário que calcula as necessidades de materiais e componentes necessários para a produção. Ele usa informações do MPS para programar a compra e entrega de materiais de forma a atender ao cronograma de produção, minimizando os níveis de estoque.
#
# - **ERP (Enterprise Resource Planning):** ERP é um sistema de software integrado que gerencia todas as operações de uma empresa, incluindo planejamento, compras, estoque, vendas, marketing, finanças e recursos humanos.
#
# Para determinar o MPS definimos as seguintes variáveis:
#
# - **Demanda:** Sempre o maior valor entre Demanda preista e Pedidos em carteira
# - **Tipo de produção:** Acompanha a demanda ou Nivelamento ($Produção = \frac { \sum Demanda + Estoque \ minimo - Estoque \ inicial}{Tempo \ total}$)
# - **Lote minimo**
# - **Estoque de segurança**
# - **Tempo de produção**
# - **Exemplo:**
#
# ![image.png](attachment:52e6234e-7d23-4ee5-b0e0-9615479544d6.png)
#
# Determinado o MPS é definido quais os materiais que são necessarios para a fabricação do produto, feito isso é realizado novamente o MPS para cada 1 deles e chamamos eles de MRP.

# %% [markdown]
# dados.
