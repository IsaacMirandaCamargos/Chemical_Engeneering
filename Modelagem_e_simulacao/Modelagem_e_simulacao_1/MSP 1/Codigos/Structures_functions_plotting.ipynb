# %% [markdown]
# <h1 align="center"> Structures

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h1 align="center"> Functios

# %% [markdown]
# ```
# function y = funcao(T, A, B)
#     y = retorna_algo
#
# endfunction
# ```

# %% [markdown]
# <h1 align="center"> Plotting

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
