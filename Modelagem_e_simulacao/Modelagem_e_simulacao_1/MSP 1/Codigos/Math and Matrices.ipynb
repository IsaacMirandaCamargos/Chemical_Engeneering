# %% [markdown]
# <h1 align="center"> Diretrizes para relatorios <h1>

# %% [markdown]
# As tarefas deverão ser apresentadas na forma de artigo de acordo com o template da revista RBCTI:
#
# - https://drive.google.com/file/d/1mD7BWJbcbfoS6sqL4wTeY6_r3b3R1jKJ/view
#
# O arquivo do código do Scilab deverá ser enviado juntamente com o relatório.

# %% [markdown]
# <h1 align="center"> General functions <h1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h1 align="center"> Math <h1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h1 align="center"> Vetores e matrizes

# %% [markdown]
# ```
# interval = [1:0.1:2] # [ inicio : passo : final ]
# vetor_row = [1 2 3 4] ou [1, 2, 3, 4]
# vetor_column = [1; 2; 3; 4]
# matrix = [1 2 3; 4 5 6; 7 8 9]
#
# ```

# %% [markdown]
# <h1 align="center"> Matrices slicing <h1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h1 align="center"> Matrices functions <h1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
